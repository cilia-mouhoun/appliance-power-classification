# %%
fig, axes = plt.subplots(5, 1, figsize=(12, 12))

for class_label in range(5):
    idx = np.where(y == class_label)[0][0]
    axes[class_label].plot(X.iloc[idx].values, label=f'Class {class_label}')
    axes[class_label].set_title(f'Sample Time-Series - Class {class_label}')
    axes[class_label].set_ylabel('Power (W)')
    axes[class_label].grid(True)
    axes[class_label].legend()

axes[-1].set_xlabel('Time Step')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize Sample Time-Series

# %%
print("Data Statistics:")
print(X.describe())
print(f"\nMissing values: {X.isnull().sum().sum()}")
print(f"Data type: {X.dtypes.unique()}")

# %% [markdown]
# ## Basic Statistics and Data Quality

# %%
# Create sample data for demonstration
np.random.seed(42)
n_samples = 1000
n_timepoints = 256

# Create synthetic time-series data
data_list = []
for i in range(n_samples):
    # Different patterns for different classes
    class_label = i % 5  # 5 classes
    
    # Generate time-series with class-specific patterns
    t = np.linspace(0, 4*np.pi, n_timepoints)
    if class_label == 0:
        ts = 10 + 5*np.sin(t) + np.random.normal(0, 0.5, n_timepoints)
    elif class_label == 1:
        ts = 15 + 3*np.sin(2*t) + np.random.normal(0, 0.5, n_timepoints)
    elif class_label == 2:
        ts = 20 + 2*np.sin(t) + np.sin(2*t) + np.random.normal(0, 0.5, n_timepoints)
    elif class_label == 3:
        ts = 8 + 4*np.cos(t) + np.random.normal(0, 0.5, n_timepoints)
    else:
        ts = 12 + np.sin(3*t) + np.random.normal(0, 0.5, n_timepoints)
    
    data_list.append(ts)

# Create a dataframe
X = pd.DataFrame(data_list)
y = pd.Series([i % 5 for i in range(n_samples)], name='class')

print(f"Dataset shape: {X.shape}")
print(f"Classes: {sorted(y.unique())}")
print(f"\nClass distribution:")
print(y.value_counts().sort_index())

# %% [markdown]
# ## Load and Explore Raw Data

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Add src directory to path
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.utils.config import Config
from src.preprocessing import cleaning, normalization

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Exploratory Data Analysis - Time Series Classification
#
# This notebook focuses on exploring the raw time-series data, understanding its structure, distribution, and characteristics.
